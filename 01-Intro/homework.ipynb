# %%
from openai import OpenAI
import os
import requests

# %% [markdown]
# ## to access local network, i used local tunnel, from your terminal, run
# sudo npm install -g localtunnel
#
# lt --port 1234 --local-host localhost

# %%
 llm = OpenAI(
        base_url="https://sour-clowns-float.loca.lt/v1",
        api_key="lm-studio"
    )

# %%
response = llm.chat.completions.create(
    model="TheBloke/una-cybertron-7B-v2-GGUF",
    max_tokens=500,
    temperature=0.7,
    messages=[
        #{"role": "system", "content": system_prompt},
        {"role": "user", "content": "is it too late to join the course"}
    ]
)

print(response.choices[0].message.content)
# Out:
# It's never too late to learn, especially when it comes to pursuing personal growth and acquiring new skills. However, the timing of joining a course may impact your experience and opportunities for interaction with your peers or instructors. If you have concerns about enrolling in a particular course now, I would encourage you to reach out to the institution offering the course to get clarity on their admission policies and the current status of the class. They might be able to provide some helpful suggestions on alternative ways to attend this or similar courses at your convenience.

# %%
# Example: reuse your existing OpenAI setup
from openai import OpenAI

# Point to the local server
client = OpenAI(base_url="http://localhost:1234/v1", api_key="lm-studio")

completion = client.chat.completions.create(
  model="TheBloke/una-cybertron-7B-v2-GGUF",
  messages=[
    {"role": "system", "content": "Always answer in rhymes."},
    {"role": "user", "content": "Introduce yourself."}
  ],
  temperature=0.7,
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/httpx/_transports/default.py:72, in map_httpcore_exceptions()
#      71 try:
# ---> 72     yield
#      73 except Exception as exc:
#
# File ~/.local/lib/python3.12/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.local/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# ...

# %%
requests.post("http://localhost:1234/v1", data={"text": "Your query here"})
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/urllib3/connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File ~/.local/lib/python3.12/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/.local/lib/python3.12/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
# ...

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.schema.output_parser import StrOutputParser

# %%
llm = ChatOpenAI(
        base_url="https://spotty-islands-tap.loca.lt/v1",
        api_key="lm-studio",
        temperature=0.6
    )

# %%
application_prompt = """Given the following short description
    of a particular topic, write 3 attention-grabbing headlines 
    for a blog post. Reply with only the titles, one on each line,
    with no additional text.
    DESCRIPTION:
    {user_input}
"""
user_input = """AI Orchestration with LangChain and LlamaIndex
    keywords: Generative AI, applications, LLM, chatbot"""

# %%
prompt = PromptTemplate(  
    input_variables=["user_input"],
    template=application_prompt
)
chain = prompt | llm | StrOutputParser()
result = chain.invoke({"user_input": user_input})

print(result)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[23], line 6
#       1 prompt = PromptTemplate(
#       2     input_variables=["user_input"],
#       3     template=application_prompt
#       4 )
#       5 chain = prompt | llm | StrOutputParser()
# ----> 6 result = chain.invoke({"user_input": user_input})
#       8 print(result)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/runnables/base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# ...
